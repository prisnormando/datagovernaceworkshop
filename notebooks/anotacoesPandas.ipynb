# %% [markdown]
# # Notas para uso do Pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Instalações, importações e carregamentos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Carregando os dados

# %%
esus = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vacs_o.csv', sep=',', low_memory=False).sort_index(axis=1, ascending=True)

# %%
# !head '/content/drive/MyDrive/Colab Notebooks/vacs_o.csv'
# Out:
# ,_index,_type,_id,_score,_source.sistema_origem,_source.paciente_endereco_coPais,_source.vacina_codigo,_source.vacina_fabricante_nome,_source.vacina_nome,_source.estabelecimento_razaoSocial,_source.paciente_enumSexoBiologico,_source.paciente_endereco_uf,_source.data_importacao_rnds,_source.paciente_racaCor_valor,_source.vacina_categoria_codigo,_source.estabelecimento_valor,_source.paciente_id,_source.vacina_lote,_source.data_importacao_datalake,_source.estabelecimento_uf,_source.@timestamp,_source.paciente_nacionalidade_enumNacionalidade,_source.estabelecimento_municipio_codigo,_source.vacina_descricao_dose,_source.vacina_numDose,_source.status,_source.paciente_dataNascimento,_source.vacina_grupoAtendimento_codigo,_source.document_id,_source.paciente_racaCor_codigo,_source.vacina_dataAplicacao,_source.paciente_endereco_cep,_source.paciente_endereco_nmPais,_source.vacina_categoria_nome,_source.vacina_fabricante_referencia,_source.paciente_endereco_coIbgeMunicipio,_source.paciente_idad
# ...

# %% [markdown]
# ## Explorando os dados

# %%
esus.head()
# Out:
#    Unnamed: 0                                        _id              _index  \
# 0           0  ee00c04b-89ec-4ea9-9d27-cd5d71b84647-i0b0  desc-imunizacao-v5
# 1           1  8d0318f3-edb2-4746-85c9-b1463ca3baa5-i0b0  desc-imunizacao-v5
# 2           2  462c01a2-625f-401d-a5b7-54a1e6fb04e6-i0b0  desc-imunizacao-v5
# 3           3  576f6c22-35b5-4706-a6cb-07feac94039e-i0b0  desc-imunizacao-v5
# 4           4  996a75d5-d631-4e27-bfda-248fc01ec7c3-i0b0  desc-imunizacao-v5
#
#    _score        _source.@timestamp  _source.@version  \
# 0     1.0  2022-08-22T09:15:41.631Z                 1
# 1     1.0  2022-08-22T09:15:41.632Z                 1
# 2     1.0  2022-08-22T09:15:41.634Z                 1
# 3     1.0  2022-08-22T09:15:41.636Z                 1
# 4     1.0  2022-08-22T09:15:41.641Z                 1
#
#   _source.data_importacao_datalake _source.data_importacao_rnds  \
# 0         2022-08-22T06:07:37.000Z     2022-08-22T06:02:55.000Z
# ...

# %%
shape = esus.shape
print('\nTotal de registros :', shape[0],'\nTotal de variáveis :', shape[1])
# Out:
# Total de registros : 100
# Total de variáveis : 45

# %%
esus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 45 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Unnamed: 0                                        100 non-null    int64
#  1   _id                                               100 non-null    object
#  2   _index                                            100 non-null    object
#  3   _score                                            100 non-null    float64
#  4   _source.@timestamp                                100 non-null    object
#  5   _source.@version                                  100 non-null    int64
#  6   _source.data_importacao_datalake                  100 non-null    object
#  7   _source.data_importacao_rnds                      100 non-null    object
#  8   _source.document_id                               100 non-null    object
# ...

# %%
esus.describe()
# Out:
#        Unnamed: 0  _score  _source.@version  _source.dt_deleted  \
# count  100.000000   100.0             100.0                 0.0
# mean    49.500000     1.0               1.0                 NaN
# std     29.011492     0.0               0.0                 NaN
# min      0.000000     1.0               1.0                 NaN
# 25%     24.750000     1.0               1.0                 NaN
# 50%     49.500000     1.0               1.0                 NaN
# 75%     74.250000     1.0               1.0                 NaN
# max     99.000000     1.0               1.0                 NaN
#
#        _source.estabelecimento_municipio_codigo  \
# count                                100.000000
# mean                              240097.250000
# std                                94689.745425
# min                               120040.000000
# 25%                               130340.000000
# 50%                               231290.000000
# ...

# %%
esus['_source.paciente_idade'].describe()
# Out:
# count    100.000000
# mean      36.130000
# std       19.536888
# min        3.000000
# 25%       21.000000
# 50%       37.000000
# 75%       46.500000
# max       91.000000
# Name: _source.paciente_idade, dtype: float64

# %%
esus['_source.paciente_idade'].mean()
# Out:
# 36.13

# %%
esus['_source.paciente_idade'].median()
# Out:
# 37.0

# %%
esus['_source.paciente_idade'].count()
# Out:
# 100

# %% [markdown]
# ## Análise categorial e visualizações

# %%
esus.head()
# Out:
#    Unnamed: 0                                        _id              _index  \
# 0           0  ee00c04b-89ec-4ea9-9d27-cd5d71b84647-i0b0  desc-imunizacao-v5
# 1           1  8d0318f3-edb2-4746-85c9-b1463ca3baa5-i0b0  desc-imunizacao-v5
# 2           2  462c01a2-625f-401d-a5b7-54a1e6fb04e6-i0b0  desc-imunizacao-v5
# 3           3  576f6c22-35b5-4706-a6cb-07feac94039e-i0b0  desc-imunizacao-v5
# 4           4  996a75d5-d631-4e27-bfda-248fc01ec7c3-i0b0  desc-imunizacao-v5
#
#    _score        _source.@timestamp  _source.@version  \
# 0     1.0  2022-08-22T09:15:41.631Z                 1
# 1     1.0  2022-08-22T09:15:41.632Z                 1
# 2     1.0  2022-08-22T09:15:41.634Z                 1
# 3     1.0  2022-08-22T09:15:41.636Z                 1
# 4     1.0  2022-08-22T09:15:41.641Z                 1
#
#   _source.data_importacao_datalake _source.data_importacao_rnds  \
# 0         2022-08-22T06:07:37.000Z     2022-08-22T06:02:55.000Z
# ...

# %%
esus['_source.paciente_idade'].value_counts()
# Out:
# 37    4
# 4     4
# 45    4
# 41    4
# 46    3
# 16    3
# 19    3
# 5     3
# 48    3
# 75    3
# 32    3
# 31    3
# 39    3
# 50    3
# 12    2
# 24    2
# 60    2
# 23    2
# 40    2
# 14    2
# 21    2
# 29    2
# 36    2
# 44    2
# 38    2
# 59    2
# 43    2
# 51    1
# 35    1
# 8     1
# 33    1
# 53    1
# 25    1
# 82    1
# 74    1
# 20    1
# 54    1
# 6     1
# 22    1
# 42    1
# 27    1
# 91    1
# 55    1
# 72    1
# 3     1
# 71    1
# 34    1
# 30    1
# 18    1
# 28    1
# 62    1
# 58    1
# 13    1
# 17    1
# 52    1
# Name: _source.paciente_idade, dtype: int64

# %%
corr = esus.corr()

corr
# Out:
#                                            Unnamed: 0  _score  \
# Unnamed: 0                                   1.000000     NaN
# _score                                            NaN     NaN
# _source.@version                                  NaN     NaN
# _source.dt_deleted                                NaN     NaN
# _source.estabelecimento_municipio_codigo    -0.071845     NaN
# _source.estabelecimento_valor               -0.141641     NaN
# _source.id_sistema_origem                    0.031770     NaN
# _source.paciente_endereco_coIbgeMunicipio   -0.089855     NaN
# _source.paciente_endereco_coPais                  NaN     NaN
# _source.paciente_idade                       0.134952     NaN
# _source.paciente_racaCor_codigo              0.007316     NaN
# _source.vacina_categoria_codigo              0.071112     NaN
# _source.vacina_codigo                       -0.019318     NaN
# _source.vacina_grupoAtendimento_codigo       0.052187     NaN
# ...

# %%
esus['_source.paciente_idade'].value_counts().plot(kind='hist', figsize=(6,6))

# %%
ax = esus['_source.paciente_idade'].value_counts().plot(kind='bar', figsize=(14,6))
ax.set_ylabel('Quantidade de pacientes')
ax.set_xlabel('Idade do paciente')
# Out:
# Text(0.5, 0, 'Idade do paciente')

# %%
esus['_source.paciente_idade'].head()
esus['_source.paciente_idade'] = esus[] + esus[]
esus.loc[esus['_source.paciente_idade'] == , ].mean()
esus.loc[esus['_source.paciente_idade'] == , ].head()
esus.loc[esus['_source.paciente_idade'] == , ].mean()

# %%
esus.head()
(esus['_source.paciente_idade'] != esus['_source.paciente_idade']).sum()
# Out:
# 0

# %%
esus['_source.paciente_idade'] *= 3

# %%
esus['_source.paciente_idade'].plot(kind='hist', bins=100, figsize=(14,6))

# %%
fig = plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %%
esus.plot(kind='scatter', x='_source.paciente_idade', y='_source.paciente_racaCor_codigo', figsize=(6,6))

# %%
esus['_source.paciente_idade'].plot(kind='density', figsize=(14,6))

# %%
boxplot_cols = ['_source.paciente_idade']

esus[boxplot_cols].plot(kind='box', subplots=True, layout=(2,3), figsize=(14,8))
# Out:
# _source.paciente_idade    AxesSubplot(0.125,0.536818;0.227941x0.343182)
# dtype: object

# %%
ax = esus['_source.paciente_idade'].plot(kind='density', figsize=(14,6))
ax.axvline(esus['_source.paciente_idade'].mean(), color='red')
ax.axvline(esus['_source.paciente_idade'].median(), color='green')

# %%
ax = esus['_source.paciente_idade'].plot(kind='hist', figsize=(14,6))
ax.set_ylabel('Quantidade')
ax.set_xlabel('Idade')
# Out:
# Text(0.5, 0, 'Idade')
